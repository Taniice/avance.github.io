# %% [markdown]
# <a href="https://colab.research.google.com/github/Taniice/avance.github.io/blob/master/ProyectoCD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 'hola'
y = 'Pamela'
print( x + ' '+  y)
# Out:
# hola Pamela

# %%
#aqui empezamos a hacer el trabajo
